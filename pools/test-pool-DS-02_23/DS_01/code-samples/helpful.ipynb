# %% [markdown]
# # Генерация случайно числовой последовательности

# %%
import random

# %%
numbers = random.sample(range(0, 100), 15) # Случайно выбираем 15 чисел из последовательности от 0 до 100

# %%
numbers
# Out:
# [41, 19, 69, 95, 3, 74, 49, 59, 27, 51, 96, 32, 46, 12, 14]

# %% [markdown]
# # Чтение файлов

# %%
with open('../datasets/stop_words_russian.txt') as fin: # В скобочках мы указывает путь к файлу
    stop_words = fin.read()

# %%
stop_words # Это весь текст, написанный в файле 'datasets/stop_words_russian.txt'
# Out:
# 'а\nе\nи\nж\nм\nо\nна\nне\nни\nоб\nно\nон\nмне\nмои\nмож\nона\nони\nоно\nмной\nмного\nмногочисленное\nмногочисленная\nмногочисленные\nмногочисленный\nмною\nмой\nмог\nмогут\nможно\nможет\nможхо\nмор\nмоя\nмоё\nмочь\nнад\nнее\nоба\nнам\nнем\nнами\nними\nмимо\nнемного\nодной\nодного\nменее\nоднажды\nоднако\nменя\nнему\nменьше\nней\nнаверху\nнего\nниже\nмало\nнадо\nодин\nодиннадцать\nодиннадцатый\nназад\nнаиболее\nнедавно\nмиллионов\nнедалеко\nмежду\nнизко\nмеля\nнельзя\nнибудь\nнепрерывно\nнаконец\nникогда\nникуда\nнас\nнаш\nнет\nнею\nнеё\nних\nмира\nнаша\nнаше\nнаши\nничего\nначала\nнередко\nнесколько\nобычно\nопять\nоколо\nмы\nну\nнх\nот\nотовсюду\nособенно\nнужно\nочень\nотсюда\nв\nво\nвон\nвниз\nвнизу\nвокруг\nвот\nвосемнадцать\nвосемнадцатый\nвосемь\nвосьмой\nвверх\nвам\nвами\nважное\nважная\nважные\nважный\nвдали\nвезде\nведь\nвас\nваш\nваша\nваше\nваши\nвпрочем\nвесь\nвдруг\nвы\nвсе\nвторой\nвсем\nвсеми\nвремени\nвремя\nвсему\nвсего\nвсегда\nвсех\nвсею\nвсю\nвся\nвсё\nвсюду\nг\nг
# ...

# %% [markdown]
# Символ \n - это специальный символ конца строки. В файле каждое стоп-слово записано с новой строки.

# %% [markdown]
# Чтобы сделать список стоп-слов давайте применим метод ```.splitlines()```, который заделить нашу строку по элементы по символу \n

# %%
stop_words = stop_words.splitlines()

# %%
print(stop_words) # Теперь в переменной stop_words хранятся список стоп-слов
# Out:
# ['Р°', 'Рµ', 'Рё', 'Р¶', 'Рј', 'Рѕ', 'РЅР°', 'РЅРµ', 'РЅРё', 'РѕР±', 'РЅРѕ', 'РѕРЅ', 'РјРЅРµ', 'РјРѕРё', 'РјРѕР¶', 'РѕРЅР°', 'РѕРЅРё', 'РѕРЅРѕ', 'РјРЅРѕР№', 'РјРЅРѕРіРѕ', 'РјРЅРѕРіРѕС‡РёСЃР»РµРЅРЅРѕРµ', 'РјРЅРѕРіРѕС‡РёСЃР»РµРЅРЅР°СЏ', 'РјРЅРѕРіРѕС‡РёСЃР»РµРЅРЅС‹Рµ', 'РјРЅРѕРіРѕС‡РёСЃР»РµРЅРЅС‹Р№', 'РјРЅРѕСЋ', 'РјРѕР№', 'РјРѕРі', 'РјРѕРіСѓС‚', 'РјРѕР¶РЅРѕ', 'РјРѕР¶РµС‚', 'РјРѕР¶С…Рѕ', 'РјРѕСЂ', 'РјРѕСЏ', 'РјРѕС‘', 'РјРѕС‡СЊ', 'РЅР°Рґ', 'РЅРµРµ', 'РѕР±Р°', 'РЅР°Рј', 'РЅРµРј', 'РЅР°РјРё', 'РЅРёРјРё', 'РјРёРјРѕ', 'РЅРµРјРЅРѕРіРѕ', 'РѕРґРЅРѕР№', 'РѕРґРЅРѕРіРѕ', 'РјРµРЅРµРµ', 'РѕРґРЅР°Р¶РґС‹', 'РѕРґРЅР°РєРѕ', 'РјРµРЅСЏ', 'РЅРµРјСѓ', 'РјРµРЅСЊС€Рµ', 'РЅРµР№', 'РЅР°РІРµСЂС…Сѓ', 'РЅРµРіРѕ', 'РЅРёР¶Рµ', 'РјР°Р»Рѕ', 'РЅР°РґРѕ', 'РѕРґРёРЅ', 'РѕРґРёРЅРЅР°РґС†Р°С‚СЊ', 'РѕРґРёРЅРЅР°РґС†Р°С‚С‹Р№', 'РЅР°Р·Р°Рґ', 'РЅР°РёР±РѕР»РµРµ', 'РЅРµРґР°РІРЅРѕ', 'РјРёР»Р»РёРѕРЅРѕРІ', 'РЅРµРґР°Р»РµРєРѕ', 'РјРµР¶РґСѓ', 'РЅРёР·РєРѕ', 'РјРµР»СЏ', 'РЅРµР»СЊР·СЏ', 'РЅРёР±СѓРґСЊ', 'РЅРµРїСЂРµСЂС‹РІРЅРѕ', 'РЅР°РєРѕРЅРµС†
# ...

# %% [markdown]
# # Рекурсивные функции

# %% [markdown]
# Рекурсивная функция — это та, которая вызывает сама себя.

# %% [markdown]
# Например вспомним как высчитывается факториал: \
# !7 = 7 * 6 * 5 * 4 * 3 * 2 * 1 или \
# !7 = 7 * 6 * 5 * 4 * 3 * !2 или \
# !7 = 7 * 6 * 5 * 4 * !3 или \
# !7 = 7 * 6 * 5 * !4 или \
# !7 = 7 * 6 * !5 или \
# !7 = 7 * !6

# %% [markdown]
# Поэтому в функции расчета факториала, мы можем вызвать функцию факториал, но с n-1

# %%
def factorial(n):
    if n == 1: # Это условие выхода из рекурсии. Когда вы пишете рекурсивную фунцию оно ВСЕГДА быть прописано
        return n
    else:
        return n * factorial(n - 1)
